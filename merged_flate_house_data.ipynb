# %% [markdown]
# <a href="https://colab.research.google.com/github/Mrrohit0806/Capstone-project-01/blob/main/merged_flate_house_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv('/content/flats_cleaned.csv')
houses = pd.read_csv('/content/house_cleaned_01.csv')

# %%
df = pd.concat([flats, houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                                     property_name property_type  \
# 0                 2 BHK Flat in Sector 65 Gurgaon          flat
# 1                             1 BHK Flat in Sohna          flat
# 2                 2 BHK Flat in Sector 92 Gurgaon          flat
# 3  12 Bedroom House for sale in Sector 40 Gurgaon         house
# 4                             2 BHK Flat in Sohna          flat
#
#                 society  price_per_sqft  \
# 0           m3m heights         15793.0
# 1   trisara our homes 3          4339.0
# 2    sare crescent parc          5000.0
# 3           independent         40135.0
# 4  breez global heights          6420.0
#
#                              areaWithType    area  bedRoom  bathroom balcony  \
# 0  Super Built up area 1260(117.06 sq.m.)  1260.0        2         2       2
# 1        Built Up area: 484 (44.97 sq.m.)   484.0        1         1       0
# 2    Super Built up area 1000(92.9 sq.m.)  1000.0        2         2       3
# ...

# %%
df.to_csv('gurgaon_properties_cleaned_lev01.csv',index=False)
