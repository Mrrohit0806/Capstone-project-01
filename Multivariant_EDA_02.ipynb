# %% [markdown]
# <a href="https://colab.research.google.com/github/Mrrohit0806/Capstone-project-01/blob/main/Multivariant_EDA_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('/content/FE_gurgaon_properties_cleaned_lev_03.csv')

# %%
df.duplicated().sum()
# Out:
# np.int64(129)

# %%
# drop duplicates
df.drop_duplicates(inplace=True)

# %%
# drop price column
df.drop('price',axis=1,inplace=True)

# %%
df.head()
# Out:
#   property_type               society      sector  price_per_sqft  \
# 0          flat           m3m heights   sector 65         15793.0
# 1          flat   trisara our homes 3  sohna road          4339.0
# 2          flat    sare crescent parc   sector 92          5000.0
# 3         house           independent   sector 40         40135.0
# 4          flat  breez global heights  sohna road          6420.0
#
#                              areaWithType    area  bedRoom  bathroom balcony  \
# 0  Super Built up area 1260(117.06 sq.m.)  1260.0        2         2       2
# 1        Built Up area: 484 (44.97 sq.m.)   484.0        1         1       0
# 2    Super Built up area 1000(92.9 sq.m.)  1000.0        2         2       3
# 3              Plot area 263(219.9 sq.m.)  2367.0       12        12      3+
# 4    Super Built up area 623(57.88 sq.m.)   654.0        2         2       2
#
#    floorNum facing       agePossession  Price_in_Crore  super_built_up_area  \
# 0      26.0    NaN  Under Construction            1.99               1260.0
# 1       2.0    NaN           Undefined            0.21                  NaN
# 2       2.0    NaN      Moderately Old            0.50               1000.0
# 3       4.0    NaN        New Property             NaN                  NaN
# 4       2.0    NaN        New Property            0.42                623.0
#
#    built_up_area  carpet_area  study room  servant room  store room  \
# 0            NaN          NaN           0             0           0
# 1          484.0          NaN           0             0           0
# 2            NaN          NaN           0             0           0
# 3         2367.0          NaN           0             0           1
# 4            NaN          NaN           0             0           0
#
#    pooja room  others  furnishing_type  luxury_score
# 0           0       0                0            48
# 1           0       0                0             0
# 2           0       0                0            38
# 3           0       0                2            57
# 4           0       0                0            73

# %%
df.shape
# Out:
# (3831, 23)

# %% [markdown]
# **property_type vs price**

# %%
sns.barplot(x=df['property_type'], y=df['Price_in_Crore'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='Price_in_Crore'>

# %%
sns.boxplot(x=df['property_type'], y=df['Price_in_Crore'])
# Out:
# <Axes: xlabel='property_type', ylabel='Price_in_Crore'>

# %% [markdown]
# **property_type vs area**

# %%
sns.barplot(x=df['property_type'], y=df['built_up_area'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
sns.boxplot(x=df['property_type'], y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
# removing that crazy outlier
df = df[df['built_up_area'] != 737147]

# %%
sns.boxplot(x=df['property_type'], y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %% [markdown]
# **property_type vs price_per_sqft**

# %%
sns.barplot(x=df['property_type'], y=df['price_per_sqft'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
sns.boxplot(x=df['property_type'], y=df['price_per_sqft'])
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
# check outliers
df[df['price_per_sqft'] > 100000][['property_type','society','sector','Price_in_Crore','price_per_sqft','area','areaWithType', 'super_built_up_area', 'built_up_area', 'carpet_area']]
# Out:
#      property_type                      society  \
# 246          house                  independent
# 307          house            vatika india next
# 412           flat           ambience caitriona
# 581          house                  independent
# 684          house         bhim nagar, sector 6
# 864          house       unitech deerwood chase
# 902          house          huda plot sector 38
# 1089         house                dlf the grove
# 1123         house       dlf city plots phase 2
# 1335         house         eros rosewood villas
# 1445         house                  independent
# 1495         house                        ansal
# 1558         house  unitech nirvana birch court
# 1627         house               uppal southend
# 1776         house                  independent
# 2003         house                  independent
# 2061         house                    rk excelo
# 2197         house                  independent
# 2293         house                  independent
# 2426         house                  independent
# 2650         house           vipul tatvam villa
# 2750         house                  independent
# 2873         house                   ardee city
# 2925         house                  independent
# 2926         house                  independent
# 2980         house                  independent
# 3096         house     unitech uniworld resorts
# 3251         house                  independent
# 3277         house       emaar the palm springs
# 3527         house       dlf city plots phase 2
# 3582         house                  independent
# 3791         house     unitech uniworld resorts
# 3857         house                  independent
# 3903         house                  independent
#
#                                 sector  Price_in_Crore  price_per_sqft   area  \
# 246                           sector 4             NaN        105263.0   57.0
# 307                          sector 82             NaN        194444.0  360.0
# 412                          sector 24            14.0        200000.0  700.0
# 581                          sector 28             NaN        125000.0  360.0
# 684                         bhim nagar             NaN        126865.0   67.0
# 864                          sector 50             NaN        235376.0  359.0
# 902                          sector 38             NaN        245398.0  175.0
# 1089                         sector 54             NaN        211111.0  270.0
# 1123                         sector 25             NaN        261194.0  402.0
# 1335                         sector 49             NaN        178571.0  154.0
# 1445                         sector 12             NaN        133079.0  263.0
# 1495                         sector 43             NaN        308333.0   60.0
# 1558                         sector 50             NaN        283333.0  251.0
# 1627                         sector 49             NaN        290948.0  232.0
# 1776                         sector 55             NaN        241666.0   60.0
# 2003                             kheri             NaN        138888.0   54.0
# 2061                         sector 12             NaN        120000.0   50.0
# 2197                         sector 38             NaN        230547.0  347.0
# 2293                    huda sector 28             NaN        144444.0   45.0
# 2426                         sector 23             NaN        161849.0  173.0
# 2650                         sector 48             NaN        201388.0  360.0
# 2750                         sector 12             NaN        315789.0  190.0
# 2873                         sector 52             NaN        183333.0  300.0
# 2925                         sector 24             NaN        229885.0  435.0
# 2926                  golf course road             NaN        160000.0  100.0
# 2980  hsiidc plot sector 1 imt manesar             NaN        122222.0  818.0
# 3096                         sector 33             NaN        173992.0  546.0
# 3251              sector 21a faridabad             NaN        105751.0  539.0
# 3277                         sector 54             NaN        600000.0  400.0
# 3527                         sector 25             NaN        400000.0  250.0
# 3582                         sector 57             NaN        266666.0  300.0
# 3791                         sector 33             NaN        181818.0  550.0
# 3857                         sector 54             NaN        234375.0  160.0
# 3903                         sector 17             NaN        218750.0  160.0
#
#                                            areaWithType  super_built_up_area  \
# 246                             Plot area 57(5.3 sq.m.)                  NaN
# 307   Plot area 360(33.45 sq.m.)Built Up area: 3900 ...                  NaN
# 412                    Built Up area: 700 (65.03 sq.m.)                  NaN
# 581                    Built Up area: 360 (33.45 sq.m.)                  NaN
# 684                            Plot area 67(6.22 sq.m.)                  NaN
# 864                          Plot area 359(33.35 sq.m.)                  NaN
# 902   Plot area 163(15.14 sq.m.)Built Up area: 145 s...                  NaN
# 1089                   Built Up area: 270 (25.08 sq.m.)                  NaN
# 1123                         Plot area 402(37.35 sq.m.)                  NaN
# 1335  Plot area 154(14.31 sq.m.)Carpet area: 1650 sq...                  NaN
# 1445  Plot area 263(24.43 sq.m.)Built Up area: 4800 ...                  NaN
# 1495                           Plot area 60(5.57 sq.m.)                  NaN
# 1558                          Plot area 240(22.3 sq.m.)                  NaN
# 1627                         Plot area 232(21.55 sq.m.)                  NaN
# 1776                           Plot area 60(5.57 sq.m.)                  NaN
# 2003                           Plot area 54(5.02 sq.m.)                  NaN
# 2061  Plot area 50(4.65 sq.m.)Built Up area: 30 sq.f...                  NaN
# 2197  Built Up area: 347 (32.24 sq.m.)Carpet area: 2...                  NaN
# 2293                           Plot area 45(4.18 sq.m.)                  NaN
# 2426  Plot area 173(16.07 sq.m.)Built Up area: 160 s...                  NaN
# 2650                         Plot area 360(33.45 sq.m.)                  NaN
# 2750  Plot area 190(17.65 sq.m.)Carpet area: 1600 sq...                  NaN
# 2873                         Plot area 300(27.87 sq.m.)                  NaN
# 2925                     Carpet area: 435 (40.41 sq.m.)                  NaN
# 2926                          Plot area 100(9.29 sq.m.)                  NaN
# 2980                         Plot area 900(83.61 sq.m.)                  NaN
# 3096                         Plot area 546(50.73 sq.m.)                  NaN
# 3251                         Plot area 539(50.07 sq.m.)                  NaN
# 3277                         Plot area 400(37.16 sq.m.)                  NaN
# 3527                         Plot area 250(23.23 sq.m.)                  NaN
# 3582                         Plot area 300(27.87 sq.m.)                  NaN
# 3791                          Plot area 550(51.1 sq.m.)                  NaN
# 3857                         Plot area 160(14.86 sq.m.)                  NaN
# 3903                   Built Up area: 160 (14.86 sq.m.)                  NaN
#
#       built_up_area  carpet_area
# 246            57.0          NaN
# 307          3900.0       3743.0
# 412           700.0          NaN
# 581           360.0          NaN
# 684            67.0          NaN
# 864           359.0          NaN
# 902           145.0          NaN
# 1089          270.0          NaN
# 1123          402.0          NaN
# 1335            NaN       1650.0
# 1445         4800.0       4400.0
# 1495           60.0          NaN
# 1558          240.0          NaN
# 1627          232.0          NaN
# 1776           60.0          NaN
# 2003           54.0          NaN
# 2061           30.0         15.0
# 2197          347.0        215.0
# 2293           45.0          NaN
# 2426          160.0        150.0
# 2650          360.0          NaN
# 2750            NaN       1600.0
# 2873          300.0          NaN
# 2925            NaN        435.0
# 2926          100.0          NaN
# 2980          900.0          NaN
# 3096          546.0          NaN
# 3251          539.0          NaN
# 3277          400.0          NaN
# 3527          250.0          NaN
# 3582          300.0          NaN
# 3791          550.0          NaN
# 3857          160.0          NaN
# 3903          160.0          NaN

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['bedRoom']))
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
# checking outliers
df[df['bedRoom'] >= 10]
# Out:
#      property_type                    society         sector  price_per_sqft  \
# 3            house                independent      sector 40         40135.0
# 187          house  floor wise designer kothi      sector 25         48148.0
# 201          house                independent      sector 40         38986.0
# 404          house                independent  shivaji nagar         25000.0
# 417          house                independent      sector 43         39062.0
# ...            ...                        ...            ...             ...
# 3628         house                independent      sector 43         38760.0
# 3784         house                independent      sector 25         28490.0
# 3803         house                independent      sector 54         38194.0
# 3866         house             uppal southend      sector 49         31915.0
# 3902         house                independent      sector 43          6875.0
#
#                       areaWithType    area  bedRoom  bathroom balcony  \
# 3       Plot area 263(219.9 sq.m.)  2367.0       12        12      3+
# 187    Plot area 300(250.84 sq.m.)  2700.0       12        16      3+
# 201    Plot area 342(285.96 sq.m.)  3078.0       16        16      3+
# 404    Plot area 200(167.23 sq.m.)  1800.0       16        16      3+
# 417    Plot area 128(107.02 sq.m.)  1152.0       20        20      3+
# ...                            ...     ...      ...       ...     ...
# 3628   Plot area 215(179.77 sq.m.)  1935.0       12        12      3+
# 3784   Plot area 351(293.48 sq.m.)  3159.0       10        10       3
# 3803   Plot area 160(133.78 sq.m.)  1440.0       18        18      3+
# 3866   Plot area 235(196.49 sq.m.)  2115.0       12        12      3+
# 3902  Plot area 3200(297.29 sq.m.)  3200.0       12        12      3+
#
#       floorNum      facing   agePossession  Price_in_Crore  \
# 3          4.0         NaN    New Property             NaN
# 187        4.0  North-East    New Property             NaN
# 201        4.0         NaN    New Property             NaN
# 404        4.0       South  Relatively New             NaN
# 417        4.0        East  Relatively New             NaN
# ...        ...         ...             ...             ...
# 3628       4.0        East    New Property             NaN
# 3784       3.0        East    Old Property             NaN
# 3803       4.0  South-West  Relatively New             NaN
# 3866       3.0        West  Moderately Old             NaN
# 3902       6.0       North    New Property             NaN
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 3                     NaN         2367.0          NaN           0
# 187                   NaN         2700.0          NaN           1
# 201                   NaN         3078.0          NaN           1
# 404                   NaN         1800.0          NaN           0
# 417                   NaN         1152.0          NaN           0
# ...                   ...            ...          ...         ...
# 3628                  NaN         1935.0          NaN           1
# 3784                  NaN         3159.0          NaN           0
# 3803                  NaN         1440.0          NaN           0
# 3866                  NaN         2115.0          NaN           0
# 3902                  NaN         3200.0          NaN           0
#
#       servant room  store room  pooja room  others  furnishing_type  \
# 3                0           1           0       0                2
# 187              1           1           1       0                2
# 201              1           1           1       0                2
# 404              0           0           0       0                2
# 417              1           0           0       0                1
# ...            ...         ...         ...     ...              ...
# 3628             1           1           1       0                2
# 3784             0           0           1       0                2
# 3803             1           0           0       0                1
# 3866             0           0           0       1                0
# 3902             1           0           0       0                1
#
#       luxury_score
# 3               57
# 187            144
# 201              0
# 404             20
# 417             22
# ...            ...
# 3628            72
# 3784            64
# 3803            70
# 3866            49
# 3902            50
#
# [76 rows x 23 columns]

# %%
sns.barplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
sns.boxplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
# checking for outliers
df[(df['property_type'] == 'house') & (df['floorNum'] > 10)]
# Out:
#      property_type                  society            sector  price_per_sqft  \
# 244          house              spaze privy         sector 72          6981.0
# 261          house        suncity avenue 76         sector 76         10067.0
# 514          house           dlf the arbour         sector 63         21519.0
# 965          house              greenopolis         sector 89          5397.0
# 1522         house  indiabulls centrum park        sector 103          8125.0
# 2069         house          godrej meridien        sector 106         14000.0
# 2146         house      satya the hermitage        sector 103          6702.0
# 2284         house   vatika the seven lamps         sector 82          6597.0
# 2332         house              spaze privy         sector 72          8486.0
# 2926         house              independent  golf course road        160000.0
# 3031         house              independent         sector 92          7627.0
# 3319         house           ats tourmaline        sector 109          8697.0
# 3362         house               ninex city         sector 76          6250.0
# 3592         house      ireo victory valley         sector 67         22222.0
# 3604         house         suncity township         sector 54         30968.0
#
#                                            areaWithType    area  bedRoom  \
# 244   Built Up area: 3653 (339.37 sq.m.)Carpet area:...  4426.0        5
# 261   Plot area 745(69.21 sq.m.)Built Up area: 745 s...   745.0        2
# 514                  Built Up area: 3950 (366.97 sq.m.)  3950.0        4
# 965                   Built Up area: 1297 (120.5 sq.m.)  1297.0        2
# 1522                       Plot area 4000(371.61 sq.m.)  4000.0        4
# 2069                       Plot area 4000(371.61 sq.m.)  4000.0        5
# 2146                 Built Up area: 4700 (436.64 sq.m.)  4700.0        4
# 2284                       Plot area 2425(225.29 sq.m.)  2425.0        4
# 2332                       Plot area 3653(339.37 sq.m.)  3653.0        5
# 2926                          Plot area 100(9.29 sq.m.)   100.0        3
# 3031                 Built Up area: 2360 (219.25 sq.m.)  2360.0        4
# 3319                 Built Up area: 2150 (199.74 sq.m.)  2150.0        3
# 3362                   Carpet area: 2800 (260.13 sq.m.)  2800.0        4
# 3592                        Plot area 400(334.45 sq.m.)  3600.0        6
# 3604  Plot area 60Built Up area: 60 sq.m.Carpet area...   646.0        9
#
#       bathroom balcony  floorNum      facing       agePossession  \
# 244          5      3+      14.0        East      Relatively New
# 261          2       2      11.0  North-East        New Property
# 514          4      3+      27.0         NaN           Undefined
# 965          2       2      14.0  North-East           Undefined
# 1522         3      3+      20.0         NaN  Under Construction
# 2069         4      3+      33.0  North-East        New Property
# 2146         5       0      12.0        East           Undefined
# 2284         4      3+      16.0       North      Moderately Old
# 2332         5      3+      21.0         NaN      Relatively New
# 2926         2       2      41.0         NaN      Relatively New
# 3031         5       0      13.0         NaN           Undefined
# 3319         4       0      12.0         NaN           Undefined
# 3362         4       0      14.0         NaN           Undefined
# 3592         7      3+      51.0  North-East      Moderately Old
# 3604         9       3      11.0       North      Relatively New
#
#       Price_in_Crore  super_built_up_area  built_up_area  carpet_area  \
# 244              NaN                  NaN         3653.0       2922.0
# 261              NaN                  NaN          745.0          NaN
# 514              NaN                  NaN         3950.0          NaN
# 965              NaN                  NaN         1297.0          NaN
# 1522             NaN                  NaN         4000.0          NaN
# 2069             NaN                  NaN         4000.0          NaN
# 2146             NaN                  NaN         4700.0          NaN
# 2284             NaN                  NaN         2425.0          NaN
# 2332             NaN                  NaN         3653.0          NaN
# 2926             NaN                  NaN          100.0          NaN
# 3031             NaN                  NaN         2360.0          NaN
# 3319             NaN                  NaN         2150.0          NaN
# 3362             NaN                  NaN            NaN       2800.0
# 3592             NaN                  NaN         3600.0          NaN
# 3604             NaN                  NaN           60.0         59.0
#
#       study room  servant room  store room  pooja room  others  \
# 244            0             1           0           0       0
# 261            0             0           0           0       0
# 514            0             0           0           0       0
# 965            0             0           0           0       0
# 1522           0             0           0           0       0
# 2069           1             1           1           1       0
# 2146           0             0           0           0       0
# 2284           0             1           0           0       0
# 2332           0             0           0           0       0
# 2926           0             0           0           0       0
# 3031           0             0           0           0       0
# 3319           0             0           0           0       0
# 3362           0             0           0           0       0
# 3592           1             1           0           1       0
# 3604           0             1           0           0       0
#
#       furnishing_type  luxury_score
# 244                 2            33
# 261                 0            40
# 514                 0            61
# 965                 0             0
# 1522                0            51
# 2069                0           151
# 2146                0            61
# 2284                0            94
# 2332                0             0
# 2926                0             0
# 3031                0             0
# 3319                0             0
# 3362                0             0
# 3592                2            49
# 3604                1             7

# %% [markdown]
# *  conclusion houses(villa) but in appartments

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['agePossession']))
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='agePossession',values='Price_in_Crore',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
plt.figure(figsize=(15,4))
sns.heatmap(pd.pivot_table(df,index='property_type',columns='bedRoom',values='Price_in_Crore',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['furnishing_type']))
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='furnishing_type',values='Price_in_Crore',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.barplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
sns.boxplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
df.head()
# Out:
#   property_type               society      sector  price_per_sqft  \
# 0          flat           m3m heights   sector 65         15793.0
# 1          flat   trisara our homes 3  sohna road          4339.0
# 2          flat    sare crescent parc   sector 92          5000.0
# 3         house           independent   sector 40         40135.0
# 4          flat  breez global heights  sohna road          6420.0
#
#                              areaWithType    area  bedRoom  bathroom balcony  \
# 0  Super Built up area 1260(117.06 sq.m.)  1260.0        2         2       2
# 1        Built Up area: 484 (44.97 sq.m.)   484.0        1         1       0
# 2    Super Built up area 1000(92.9 sq.m.)  1000.0        2         2       3
# 3              Plot area 263(219.9 sq.m.)  2367.0       12        12      3+
# 4    Super Built up area 623(57.88 sq.m.)   654.0        2         2       2
#
#    floorNum facing       agePossession  Price_in_Crore  super_built_up_area  \
# 0      26.0    NaN  Under Construction            1.99               1260.0
# 1       2.0    NaN           Undefined            0.21                  NaN
# 2       2.0    NaN      Moderately Old            0.50               1000.0
# 3       4.0    NaN        New Property             NaN                  NaN
# 4       2.0    NaN        New Property            0.42                623.0
#
#    built_up_area  carpet_area  study room  servant room  store room  \
# 0            NaN          NaN           0             0           0
# 1          484.0          NaN           0             0           0
# 2            NaN          NaN           0             0           0
# 3         2367.0          NaN           0             0           1
# 4            NaN          NaN           0             0           0
#
#    pooja room  others  furnishing_type  luxury_score
# 0           0       0                0            48
# 1           0       0                0             0
# 2           0       0                0            38
# 3           0       0                2            57
# 4           0       0                0            73

# %%
# sector analysis
plt.figure(figsize=(15,6))
sns.heatmap(pd.crosstab(df['property_type'],df['sector'].sort_index()))
# Out:
# <Axes: xlabel='sector', ylabel='property_type'>

# %%
# sector analysis
import re
# Group by 'sector' and calculate the average price
avg_price_per_sector = df.groupby('sector')['Price_in_Crore'].mean().reset_index()

# Function to extract sector numbers
def extract_sector_number(sector_name):
    match = re.search(r'\d+', sector_name)
    if match:
        return int(match.group())
    else:
        return float('inf')  # Return a large number for non-numbered sectors

avg_price_per_sector['sector_number'] = avg_price_per_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sector_sorted_by_sector = avg_price_per_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sector_sorted_by_sector.set_index('sector')[['Price_in_Crore']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Average Price per Sector (Sorted by Sector Number)')
plt.xlabel('Average Price')
plt.ylabel('Sector')
plt.show()

# %%
avg_price_per_sqft_sector = df.groupby('sector')['price_per_sqft'].mean().reset_index()

avg_price_per_sqft_sector['sector_number'] = avg_price_per_sqft_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sqft_sector_sorted_by_sector = avg_price_per_sqft_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sqft_sector_sorted_by_sector.set_index('sector')[['price_per_sqft']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
luxury_score = df.groupby('sector')['luxury_score'].mean().reset_index()

luxury_score['sector_number'] = luxury_score['sector'].apply(extract_sector_number)

# Sort by sector number
luxury_score_sector = luxury_score.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(luxury_score_sector.set_index('sector')[['luxury_score']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
df.head()
# Out:
#   property_type               society      sector  price_per_sqft  \
# 0          flat           m3m heights   sector 65         15793.0
# 1          flat   trisara our homes 3  sohna road          4339.0
# 2          flat    sare crescent parc   sector 92          5000.0
# 3         house           independent   sector 40         40135.0
# 4          flat  breez global heights  sohna road          6420.0
#
#                              areaWithType    area  bedRoom  bathroom balcony  \
# 0  Super Built up area 1260(117.06 sq.m.)  1260.0        2         2       2
# 1        Built Up area: 484 (44.97 sq.m.)   484.0        1         1       0
# 2    Super Built up area 1000(92.9 sq.m.)  1000.0        2         2       3
# 3              Plot area 263(219.9 sq.m.)  2367.0       12        12      3+
# 4    Super Built up area 623(57.88 sq.m.)   654.0        2         2       2
#
#    floorNum facing       agePossession  Price_in_Crore  super_built_up_area  \
# 0      26.0    NaN  Under Construction            1.99               1260.0
# 1       2.0    NaN           Undefined            0.21                  NaN
# 2       2.0    NaN      Moderately Old            0.50               1000.0
# 3       4.0    NaN        New Property             NaN                  NaN
# 4       2.0    NaN        New Property            0.42                623.0
#
#    built_up_area  carpet_area  study room  servant room  store room  \
# 0            NaN          NaN           0             0           0
# 1          484.0          NaN           0             0           0
# 2            NaN          NaN           0             0           0
# 3         2367.0          NaN           0             0           1
# 4            NaN          NaN           0             0           0
#
#    pooja room  others  furnishing_type  luxury_score
# 0           0       0                0            48
# 1           0       0                0             0
# 2           0       0                0            38
# 3           0       0                2            57
# 4           0       0                0            73

# %% [markdown]
# **price in crore**

# %%
sns.barplot(x=df['bedRoom'],y=df['Price_in_Crore'],estimator=np.median,hue=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom', ylabel='Price_in_Crore'>

# %%
sns.barplot(x=df['agePossession'],y=df['Price_in_Crore'],estimator=np.median,hue=df['agePossession'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['agePossession'],y=df['area'],estimator=np.median,hue=df['agePossession'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['furnishing_type'],y=df['Price_in_Crore'],estimator=np.median,hue=df['furnishing_type'])
# Out:
# <Axes: xlabel='furnishing_type', ylabel='Price_in_Crore'>

# %% [markdown]
# **correlation**

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.select_dtypes(include=np.number).corr(), annot=True, fmt=".2f")
# Out:
# <Axes: >

# %%
df.select_dtypes(include=np.number).corr()['Price_in_Crore'].sort_values(ascending=False)
# Out:
# Price_in_Crore         1.000000
# super_built_up_area    0.762444
# built_up_area          0.720378
# price_per_sqft         0.628961
# bathroom               0.591755
# bedRoom                0.554106
# servant room           0.427969
# floorNum               0.206136
# furnishing_type        0.186366
# luxury_score           0.178534
# pooja room             0.119788
# study room             0.067829
# store room             0.060539
# area                  -0.001954
# others                -0.012341
# carpet_area           -0.018167
# Name: Price_in_Crore, dtype: float64
